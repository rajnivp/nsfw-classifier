# %% [markdown]
# # Plot predictions and probabilities for batch and for single image

# %% [markdown]
# first import all functions from test.py file

# %%
from category.test import *

# %%
#Load model
model = load_model()
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %% [markdown]
# first plot prediction chart for batch of 20 images.
# chart plot 20 images with corresponding predicted label.

# %%
# Define mapper to map class with its predicted value
mapper = {0: "drawing-SFW", 1: "hentai-NSFW", 2: "neutral-SFW", 3: "porn-NSFW", 4: "sexy-SFW"}

# %%
# Run test loader
test_loader(model,mapper)

# %% [markdown]
# now plot chart for single image with classes and corresponding probabilities

# %%
# Path of image you want to test
image_path =  r"category\test\test\sexy78.jpg"
# prediction, classe and probabilities
pred, (probs, classes) = predict(image_path, model)

# %%
pred, probs, classes
# Out:
# (4,
#  [0.8436329960823059,
#   0.15226751565933228,
#   0.0031804610043764114,
#   0.000826804549433291,
#   9.220872743753716e-05],
#  [4, 3, 2, 1, 0])

# %%
# Plot
view_classify(image_path, probs, classes, pred, mapper)

# %%
# Path of image you want to test
image_path =  r"category\test\test\SFW (90).jpg"
# prediction, classe and probabilities
pred, (probs, classes) = predict(image_path, model)

# %%
pred, probs, classes
# Out:
# (0,
#  [0.9231818318367004,
#   0.07504022121429443,
#   0.0017266330542042851,
#   3.2434989407192916e-05,
#   1.888890801637899e-05],
#  [0, 1, 2, 4, 3])

# %%
# Plot
view_classify(image_path, probs, classes, pred, mapper)

# %%
# Path of image you want to test
image_path =  r"category\test\test\neutral16.jpg"
# prediction, classe and probabilities
pred, (probs, classes) = predict(image_path, model)

# %%
pred, probs, classes
# Out:
# (2,
#  [0.6337211728096008,
#   0.3595481216907501,
#   0.005115740932524204,
#   0.0014200772857293487,
#   0.0001948555582202971],
#  [2, 0, 4, 3, 1])

# %%
# Plot
view_classify(image_path, probs, classes, pred, mapper)

# %%
# Path of image you want to test
image_path =  r"category\test\test\neutral100.jpg"
# prediction, classe and probabilities
pred, (probs, classes) = predict(image_path, model)

# %%
pred, probs, classes
# Out:
# (4,
#  [0.4712626338005066,
#   0.31985005736351013,
#   0.18380199372768402,
#   0.02393191307783127,
#   0.0011534192599356174],
#  [4, 3, 2, 0, 1])

# %%
# Plot
view_classify(image_path, probs, classes, pred, mapper)
